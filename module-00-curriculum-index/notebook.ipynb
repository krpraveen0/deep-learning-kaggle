# %% [markdown]
# # Deep Learning from Scratch - Curriculum Index
#
# This notebook is the landing page for the full beginner curriculum.
#
# ## How to Use
# 1. Start with Module 01 and continue in order.
# 2. Run each notebook top-to-bottom.
# 3. Complete the practice tasks before moving ahead.
#
# ## Module Links
# - Module 01: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-01-intro
# - Module 02: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-02-perceptrons
# - Module 03: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-03-backprop
# - Module 04: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-04-cnns
# - Module 05: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-05-rnns
# - Module 06: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-06-transformers
# - Module 07: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-07-tips
# - Module 08: https://www.kaggle.com/code/krpraveen0/dl-from-scratch-module-08-project
#
# ## What You Will Build
# - Regression models for spending and usage prediction
# - Binary classifier with a perceptron
# - CNN image classifier
# - Sequence model with LSTM
# - Attention-based text model
# - Capstone closet assistant

# %%
modules = [
    ('01', 'Intro to Deep Learning', 'krpraveen0/dl-from-scratch-module-01-intro', '20 min'),
    ('02', 'Perceptrons and Activations', 'krpraveen0/dl-from-scratch-module-02-perceptrons', '25 min'),
    ('03', 'Backpropagation', 'krpraveen0/dl-from-scratch-module-03-backprop', '30 min'),
    ('04', 'CNNs', 'krpraveen0/dl-from-scratch-module-04-cnns', '30 min'),
    ('05', 'RNNs and LSTMs', 'krpraveen0/dl-from-scratch-module-05-rnns', '30 min'),
    ('06', 'Transformers', 'krpraveen0/dl-from-scratch-module-06-transformers', '35 min'),
    ('07', 'Training Tips', 'krpraveen0/dl-from-scratch-module-07-tips', '25 min'),
    ('08', 'Capstone Project', 'krpraveen0/dl-from-scratch-module-08-project', '45 min')
]

print('Curriculum Status Checker')
print('=' * 72)
for number, title, kernel_id, duration in modules:
    url = 'https://www.kaggle.com/code/' + kernel_id
    print(f'[ ] Module {number}: {title} ({duration})')
    print('    ' + url)

print('=' * 72)
total_minutes = sum(int(d.split()[0]) for _, _, _, d in modules)
print(f'Suggested total study time: {total_minutes} minutes')

# %%
md_lines = [
    '# Deep Learning Progress Tracker',
    '',
    'Copy this checklist into your Kaggle notes/discussion:',
    ''
]

for number, title, kernel_id, duration in modules:
    url = 'https://www.kaggle.com/code/' + kernel_id
    md_lines.append(f'- [ ] Module {number}: {title} ({duration})')
    md_lines.append(f'  - Link: {url}')

md_lines.append('')
md_lines.append(f'- Total suggested time: {sum(int(d.split()[0]) for _, _, _, d in modules)} minutes')

markdown_text = '\n'.join(md_lines)
print(markdown_text)
